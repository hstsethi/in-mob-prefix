# %% [markdown]
# ## Importing Neccessary Librariries

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Plotting Mobile Number With Prefixes 9xxx By Circle

# %%
nine_data = pd.read_csv("9xxx-mob-prefix-in.csv")
nine_data["Circle"].value_counts().plot(kind="pie", title="Numbers By Prefix 9xxx By Circle")
# Out:
# <Axes: title={'center': 'Numbers By Prefix 9xxx By Circle'}, ylabel='count'>

# %% [markdown]
# ## Plotting Mobile Number With Prefixes 8xxx By Circle

# %%
eight_data = pd.read_csv("8xxx-mob-prefix-in.csv")
eight_data["Circle"].value_counts().plot(kind="pie", title="Numbers with Prefix 8xxx By Circle")
# Out:
# <Axes: title={'center': 'Numbers with Prefix 8xxx By Circle'}, ylabel='count'>
